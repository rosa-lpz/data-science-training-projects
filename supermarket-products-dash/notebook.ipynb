# %%
import plotly.express as px
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import base64

# %% [markdown]
# # Dataset
# * Supermarket Product Images: https://www.kaggle.com/datasets/realalexanderwei/supermarket-product-images-thumbnails/data

# %% [markdown]
# ## Combined
# A convenience file containing combined information from the other CSVs. This file includes image identifiers, category assignments, and associated metadata in a single table.
# * image: Base64-encoded JPEG

# %%
df = pd.read_csv("data/combined.csv")
df
# Out:
#       category_id        id                        category  \
# 0        100e10c0  f40b49f1                         cheeses
# 1        10100008  26aa35e6  Lightweight Volumizing Shampoo
# 2        104df089  21b1eda9                     Elbow pasta
# 3        105af8b1  12b15383         Acetaminophen Chewables
# 4        105af8b1  72203d5d         Acetaminophen Chewables
# ...           ...       ...                             ...
# 15982    ffdcff08  285e3343                 Espresso Powder
# 15983    ffdcff08  801cc456                 Espresso Powder
# 15984    ffe51a86  54699bfa               Body Wash for Men
# 15985    fffc911f  55614b14                     petite peas
# 15986    fffd85a4  88a779fe                   Fresh Poultry
#
#                                                    image  width  height
# 0      /9j/4AAQSkZJRgABAQAAAQABAAD/2wCEAAkGBwgHBgkIBw...    150     150
# 1      /9j/4AAQSkZJRgABAQAAAQABAAD/2wCEAAkGBwgHBgkIBw...    142     142
# ...

# %%
df_columns =df.columns[1:]
df_columns
# Out:
# Index(['id', 'category', 'image', 'width', 'height'], dtype='object')

# %%
df_columns =df.columns
df_columns
# Out:
# Index(['category_id', 'id', 'category', 'image', 'width', 'height'], dtype='object')

# %%
categories = df['category'].unique()
categories=list(categories)
categories
# Out:
# ['cheeses',
#  'Lightweight Volumizing Shampoo',
#  'Elbow pasta',
#  'Acetaminophen Chewables',
#  'Sandwich Bags',
#  "Eggland's Best Large Brown Eggs 12 Count - Walmart.com",
#  'Arthritis Pain Reliever Gel',
#  "Men's Shampoo and Conditioner",
#  'daily moisturizing shampoo',
#  'Breakfast cereal cookies with cookies and creme flavor',
#  'Cracker assortment box',
#  'mouth rinse',
#  'sauce pot',
#  'Multivitamin/Multimineral Supplement Tablets',
#  'sweet corn',
#  'measuring set',
#  'Mixed Greens',
#  'Kids Natural Toothpaste',
#  'Pain reliever and fever reducer tablets',
#  'Alfredo sauce with roasted garlic',
#  'Parboiled Long Grain Rice',
#  'Green White Grapes',
#  'Gift Card',
#  'Extra Virgin Olive Oil with Garlic',
#  'Prep Pads',
#  'Frozen Pomegranate Arils',
#  'Carbon Zinc Battery',
#  'popcorn spritzer',
#  'Pet Carpet Cleaner',
#  'boneless pork ribeye chops',
#  'Skittles Original Chewy Candy, Full Size - 2.17 oz Bag - Walmart.com',
#  'Frozen Smoothie',
# ...

# %%
img1 = df['image'][0]
img1
# Out:
# '...'
