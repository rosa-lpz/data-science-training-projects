# %%
import plotly.express as px
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/solar.csv")
df
# Number of Solar Plants
# Number of Solar Plants
# Out:
#             State  Number of Solar Plants  Installed Capacity (MW)  \
# 0      California                     289                     4395
# 1         Arizona                      48                     1078
# 2          Nevada                      11                      238
# 3      New Mexico                      33                      261
# 4        Colorado                      20                      118
# 5           Texas                      12                      187
# 6  North Carolina                     148                      669
# 7        New York                      13                       53
#
#    Average MW Per Plant  Generation (GWh)
# 0                  15.3             10826
# 1                  22.5              2550
# 2                  21.6               557
# 3                   7.9               590
# 4                   5.9               235
# 5                  15.6               354
# 6                   4.5              1162
# 7                   4.1                84

# %% [markdown]
# # Number of Solar Plants

# %%
# Build the matplotlib figure
fig = plt.figure(figsize=(14, 5))
plt.bar(df['State'], df['Number of Solar Plants'])
plt.ylabel('Number of Solar Plants')
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'California'),
#   Text(1, 0, 'Arizona'),
#   Text(2, 0, 'Nevada'),
#   Text(3, 0, 'New Mexico'),
#   Text(4, 0, 'Colorado'),
#   Text(5, 0, 'Texas'),
#   Text(6, 0, 'North Carolina'),
#   Text(7, 0, 'New York')])
